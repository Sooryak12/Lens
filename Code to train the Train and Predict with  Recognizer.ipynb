# %%
import os
# !git clone https://github.com/Sooryak12/digix_baseline
# Out:
# Password: ··········

# %%
import cv2
import glob
import shutil
import os
from tqdm import tqdm
import json
from skimage import io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.mkdir("official_data")

os.mkdir("checkpoint")
os.mkdir("checkpoint/recognizer")

os.mkdir("output")

os.mkdir("tmp_data")
os.mkdir("tmp_data/recognizer_images")
os.mkdir("tmp_data/recognizer_txts")

# %%
os.mkdir("tmp_data/recognizer_images/train")
os.mkdir("tmp_data/recognizer_images/test")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### Clearing cache files to Restart training

# shutil.rmtree("tmp_data")
# #shutil.rmtree('recognizer/tools/dictionary/chars.txt')
# #shutil.rmtree('checkpoint')
# #shutil.rmtree('output')


# os.mkdir("tmp_data")
# os.mkdir("tmp_data/recognizer_images")
# os.mkdir("tmp_data/recognizer_images/train")
# os.mkdir("tmp_data/recognizer_images/test")
# os.mkdir("tmp_data/recognizer_txts")
#os.mkdir('output')
#os.mkdir('checkpoint')

# %%
# !unzip /content/drive/MyDrive/Huawei_Competition/2021_5_data.zip
# Out:
# Archive:  /content/drive/MyDrive/Huawei_Competition/2021_5_data.zip
#    creating: train_image_common/
#   inflating: train_image_common/train_image_common_0.PNG
#   inflating: train_image_common/train_image_common_1.JPEG
#   inflating: train_image_common/train_image_common_10.PNG
#   inflating: train_image_common/train_image_common_100.JPEG
#   inflating: train_image_common/train_image_common_1000.JPEG
#   inflating: train_image_common/train_image_common_1001.JPEG
#   inflating: train_image_common/train_image_common_1002.JPEG
#   inflating: train_image_common/train_image_common_1003.JPEG
#   inflating: train_image_common/train_image_common_1004.JPEG
#   inflating: train_image_common/train_image_common_1005.JPEG
#   inflating: train_image_common/train_image_common_1006.JPEG
#   inflating: train_image_common/train_image_common_1007.JPEG
#   inflating: train_image_common/train_image_common_1008.JPEG
#   inflating: train_image_common/train_image_common_1009.JPEG
# ...

# %%
# !python  recognizer/tools/extract_train_data.py
# Out:
# Label json file read
#
# Output train file Generated
#
# Output test file Generated
#
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# test data 0
# ...

# %%
# !python recognizer/tools/from_text_to_label.py

# %%
# change max label length in train file

# %%
# !python recognizer/train.py
# Out:
# 2021-08-30 21:44:47.977984: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-30 21:44:47.985538: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-30 21:44:47.986112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-30 21:44:48.591859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
#once model is ready ,upload null_submission file in path and predict with correct model
# Out:
# Object `tf.compat.v1.keras.backend.ctc_batch_cost` not found.

# %%
# !pip install bidict

# %%
# !python recognizer/predict.py
# Out:
# 2021-08-31 09:22:21.093264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-31 09:22:21.600394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-31 09:22:21.601509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-31 09:22:21.603236: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# # Followed by Removing those Invalid Boxes ( Indicated when predicting ) and then we submitted
